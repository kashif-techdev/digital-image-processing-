# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# 🔹 Image path
image_path = "/content/salt_pepper_noise_image.jfif"

# Read image
image = cv2.imread(image_path, 0)

if image is None:
    print("Error loading image")
    exit()

# -------------------------------
# Step 1: Add Salt & Pepper Noise
# -------------------------------
#noisy = image.copy()
#prob = 0.02

# Salt
#salt = np.random.rand(*image.shape) < prob
#noisy[salt] = 255

# Pepper
#pepper = np.random.rand(*image.shape) < prob
#noisy[pepper] = 0

# -------------------------------
# Step 2: Apply Filters
# -------------------------------

# Median Filter
median_3 = cv2.medianBlur(noisy, 3)
median_7 = cv2.medianBlur(noisy, 7)

# Min Filter (Erosion)
kernel = np.ones((3,3), np.uint8)
min_filter = cv2.erode(noisy, kernel)

# Max Filter (Dilation)
max_filter = cv2.dilate(noisy, kernel)

# -------------------------------
# Display Results
# -------------------------------

titles = [
    "Original Image",
    "Noisy Image",
    "Median (3x3)",
    "Median (7x7)",
    "Min Filter",
    "Max Filter"
]

images = [
    image,
    noisy,
    median_3,
    median_7,
    min_filter,
    max_filter
]

plt.figure(figsize=(12,8))

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()
